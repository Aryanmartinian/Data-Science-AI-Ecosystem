# %%
def func(x):
    y = x/0
try:
    func(5) # In try block the function call should be made instead of function definition
except ZeroDivisionError:
    print("ZeroDivisionError")
except NameError:
    print("NameError")
# Out:
# ZeroDivisionError

# %%
def func(x):
    print(a)
try:
    func(5)
except ZeroDivisionError:
    print("ZeroDivisionError")
except NameError:
    print("NameError")
# Out:
# NameError

# %%
try:
    listt = [1,2,3,4,5]
    print(listt[99])
except IndexError:
    print("Indexerror")
# Out:
# Indexerror

# %%
try:
    listt = [1,2,3,4,5]
    print(listt[99])
except IndexError:
    print("IndexError")
finally: # No matter what the finally block will be executed
    print("Executing rest of the code")
    print("Executing rest of the code")
# Out:
# IndexError
# Executing rest of the code
# Executing rest of the code

# %%
try:
    s = "shri"
    n = 5
    print(s+n)
except TypeError:
    print("TypeError")
# Out:
# TypeError
