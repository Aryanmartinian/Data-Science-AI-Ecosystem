# %%
# Creating a File - x mode is used to create a file, it will throw an error if the file already exists.
file1 = open("file1.txt", "x")

# %%
file1.write("Hello and Welcome to Data Science and AI Ecosystem")
file1.close()

# %%
f1 = open("file1.txt","x")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 f1 = open("file1.txt","x")
#
# File c:\Users\user\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'file1.txt'

# %%
file1 = open("file1.txt","r")
print(file1.read())
# Out:
# Hello and Welcome to Data Science and AI Ecosystem

# %%
file2 = open("file2.txt","a")
file2.write("Append Example")
file2.close()

# %%
file2 = open("file2.txt","r")
print(file2.read())
# Out:
# Append Example

# %%
file = open("file1.txt","r")
print(file.read())
# Out:
# Hello and Welcome to Data Science and AI Ecosystem

# %%
file4 = open("file3.txt","w")
file4.write("write mode open example")
file4.close()

# %%
file = open("file3.txt","r")
print(file.read())
# Out:
# write mode open example

# %%
file4 = open("file3.txt","w")
file4.write("write mode overwrite example")
file4.close()

# %%
file = open("file3.txt","r")
print(file.read())
# Out:
# write mode overwrite example

# %%
file4 = open("file3.txt","a")
file4.write("+++append mode example")
file4.close()

# %%
file = open("file3.txt","r")
print(file.read())
# Out:
# write mode overwrite example+++append mode example

# %%
import os
os.remove("file1.txt")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[17], line 2
#       1 import os
# ----> 2 os.remove("file1.txt")
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'file1.txt'

# %%
file = open("/users/Desktop/file5.txt","w")
file.write("Specific location example")
file.close()
